# %%
pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 21.0 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.3 rapidfuzz-3.6.1

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
import os
import librosa
from tqdm import tqdm
from glob import glob
import pandas as pd
import numpy as np

# %%
from jiwer import wer, cer

# %%
sylhet_main = pd.read_excel('/content/drive/MyDrive/Sylhet_Audio/Sylhet_Data.xlsx')
sylhet_main
# Out:
#      Unnamed: 0    Original                      External_ID  \
# 0           2.0  rec_01.wav               rec_01_audio_1.wav
# 1           4.0  rec_01.wav               rec_01_audio_3.wav
# 2           5.0  rec_01.wav               rec_01_audio_4.wav
# 3           6.0  rec_01.wav               rec_01_audio_5.wav
# 4           7.0  rec_01.wav               rec_01_audio_6.wav
# ..          ...         ...                              ...
# 617       619.0  rec_45.wav   rec_45_big_audio_2_chunk_0.wav
# 618       620.0  rec_45.wav           rec_45_big_audio_5.wav
# 619       621.0  rec_45.wav           rec_45_big_audio_6.wav
# 620       622.0  rec_45.wav   rec_45_big_audio_8_chunk_0.wav
# 621       623.0  rec_45.wav  rec_45_big_audio_13_chunk_1.wav
#
#                    Annotator  \
# 0    shah89@student.sust.edu
# 1      dipa.sust44@gmail.com
# 2      dipa.sust44@gmail.com
# 3      dipa.sust44@gmail.com
# 4      dipa.sust44@gmail.com
# ..                       ...
# 617  shah89@student.sust.edu
# 618  shah89@student.sust.edu
# 619  shah89@student.sust.edu
# 620  shah89@student.sust.edu
# 621  shah89@student.sust.edu
#
#                                               Contents   Time District
# 0    <> ডিউটি খরি, ডিউটি টু বাড়িত। আর তো <> আর সবকি...  161.0   Sylhet
# 1    করিয়া তারপরে রেস্ট নিলাম কিছুক্ষন, রেস্ট নেওয়া...  412.0   Sylhet
# 2    আট ঘন্টার ডিউটি পরে প্রতিদিনই। এইরকম ভাবে চেঞ্...  356.0   Sylhet
# 3    কিরকম লাগে আমরা ছাত্র-ছাত্রীরা, স্যাররা? অনেক ...  979.0   Sylhet
# 4    ডিউটিটা করতে খুব ভালা লাগে, সবকিছু মিলায়া খুব ...  675.0   Sylhet
# ..                                                 ...    ...      ...
# 617  আস্তে, আস্তে তো ওলাখান যার, যার। ফরে এখদিন এখ ...  509.0   Sylhet
# 618  ফড়ার খেত্রে তখন তারারে ডায়রি লেখিয়া দেওয়া অয়, ...  347.0   Sylhet
# 619  চেষ্টা খরি, ইসময় ফয়লা ফরীক্কা। ইটার ফরীক্কা আম...  774.0   Sylhet
# 620  নায়কর বাফে ওইলো গিয়া ইসময় জমিদারোর সেরেস্তা কি...  458.0   Sylhet
# 621  কুনু সন্তান আছিল না, নিঃসন্তান। এতো নিঃসন্তান ...  135.0   Sylhet
#
# [622 rows x 7 columns]

# %%
sylhet_main.columns
# Out:
# Index(['Unnamed: 0', 'Original', 'External_ID', 'Annotator', 'Contents',
#        'Time', 'District'],
#       dtype='object')

# %%
sylhet_main = sylhet_main.drop(labels = ['Unnamed: 0','Original','Annotator','District','Time'], axis = 1)
sylhet_main
# Out:
#                          External_ID  \
# 0                 rec_01_audio_1.wav
# 1                 rec_01_audio_3.wav
# 2                 rec_01_audio_4.wav
# 3                 rec_01_audio_5.wav
# 4                 rec_01_audio_6.wav
# ..                               ...
# 617   rec_45_big_audio_2_chunk_0.wav
# 618           rec_45_big_audio_5.wav
# 619           rec_45_big_audio_6.wav
# 620   rec_45_big_audio_8_chunk_0.wav
# 621  rec_45_big_audio_13_chunk_1.wav
#
#                                               Contents
# 0    <> ডিউটি খরি, ডিউটি টু বাড়িত। আর তো <> আর সবকি...
# 1    করিয়া তারপরে রেস্ট নিলাম কিছুক্ষন, রেস্ট নেওয়া...
# 2    আট ঘন্টার ডিউটি পরে প্রতিদিনই। এইরকম ভাবে চেঞ্...
# 3    কিরকম লাগে আমরা ছাত্র-ছাত্রীরা, স্যাররা? অনেক ...
# 4    ডিউটিটা করতে খুব ভালা লাগে, সবকিছু মিলায়া খুব ...
# ..                                                 ...
# 617  আস্তে, আস্তে তো ওলাখান যার, যার। ফরে এখদিন এখ ...
# 618  ফড়ার খেত্রে তখন তারারে ডায়রি লেখিয়া দেওয়া অয়, ...
# 619  চেষ্টা খরি, ইসময় ফয়লা ফরীক্কা। ইটার ফরীক্কা আম...
# 620  নায়কর বাফে ওইলো গিয়া ইসময় জমিদারোর সেরেস্তা কি...
# 621  কুনু সন্তান আছিল না, নিঃসন্তান। এতো নিঃসন্তান ...
#
# [622 rows x 2 columns]

# %%
len(sylhet_main)
# Out:
# 622

# %%
sylhet_b_whisper = pd.read_csv('/content/drive/MyDrive/Sylhet_Audio/Bangla_Whisper/sylhet-banglaWhisper-inferences.csv')
sylhet_b_whisper
# Out:
#                      External_ID  \
# 0                 rec_01_audio_3
# 1                 rec_01_audio_0
# 2              rec_01_audio_1(1)
# 3                 rec_01_audio_1
# 4                 rec_01_audio_2
# ..                           ...
# 617   rec_45_big_audio_1_chunk_0
# 618  rec_45_big_audio_13_chunk_1
# 619   rec_45_big_audio_2_chunk_0
# 620  rec_45_big_audio_11_chunk_0
# 621   rec_45_big_audio_8_chunk_0
#
#                                               contents
# 0    পরিয়া তারপরে লেশনীলাম কিছুবন্ড রেশনেও অভড়ে ম...
# 1    য়ঃহ্য হোন চেয়ন, আপনের দিন-কান দিনকাল কিলাহান...
# 2    মূল্পার জুটিও হরি জুটিও বাড়ির আর্টোয়ার ভেগে ...
# 3    মূল্পার জুটিও হরি জুটিও বাড়ির আর্টোয়ার ভেগে ...
# 4      কোনবালা আইনিক্তিভাবে ডিউটি ডিউটি করে চোখিন চেন।
# ..                                                 ...
# 617  ক্লাস ত্রি-ক্লাস ও গ্যাসলাম, তই সময়ে ত্রি-বিজ...
# 618  কোনো সন্তান আছিলেন, নিসন্তান, নিসন্তান ও অল ফর...
# 619  আস্তাস্তত ওলাহান যাঁরা পরে এখানে ছাড়ে আইয়া অ...
# 620  এরপরে একদিন হঠাৎ খড়িয়া তোর যে জমি কীতা উকিল ...
# 621  নায়কড় বাফে এলিক এসময় জমিদার শেরস্তা কেতে যা...
#
# [622 rows x 2 columns]

# %%
len(sylhet_b_whisper)
# Out:
# 622

# %%
for i in sylhet_b_whisper['External_ID']:
    sylhet_b_whisper['External_ID'] = sylhet_b_whisper['External_ID'].replace([i], f"{i}.wav")


sylhet_b_whisper
# Out:
#                          External_ID  \
# 0                 rec_01_audio_3.wav
# 1                 rec_01_audio_0.wav
# 2              rec_01_audio_1(1).wav
# 3                 rec_01_audio_1.wav
# 4                 rec_01_audio_2.wav
# ..                               ...
# 617   rec_45_big_audio_1_chunk_0.wav
# 618  rec_45_big_audio_13_chunk_1.wav
# 619   rec_45_big_audio_2_chunk_0.wav
# 620  rec_45_big_audio_11_chunk_0.wav
# 621   rec_45_big_audio_8_chunk_0.wav
#
#                                               contents
# 0    পরিয়া তারপরে লেশনীলাম কিছুবন্ড রেশনেও অভড়ে ম...
# 1    য়ঃহ্য হোন চেয়ন, আপনের দিন-কান দিনকাল কিলাহান...
# 2    মূল্পার জুটিও হরি জুটিও বাড়ির আর্টোয়ার ভেগে ...
# 3    মূল্পার জুটিও হরি জুটিও বাড়ির আর্টোয়ার ভেগে ...
# 4      কোনবালা আইনিক্তিভাবে ডিউটি ডিউটি করে চোখিন চেন।
# ..                                                 ...
# 617  ক্লাস ত্রি-ক্লাস ও গ্যাসলাম, তই সময়ে ত্রি-বিজ...
# 618  কোনো সন্তান আছিলেন, নিসন্তান, নিসন্তান ও অল ফর...
# 619  আস্তাস্তত ওলাহান যাঁরা পরে এখানে ছাড়ে আইয়া অ...
# 620  এরপরে একদিন হঠাৎ খড়িয়া তোর যে জমি কীতা উকিল ...
# 621  নায়কড় বাফে এলিক এসময় জমিদার শেরস্তা কেতে যা...
#
# [622 rows x 2 columns]

# %%
len(sylhet_b_whisper)
# Out:
# 622

# %%
def make_equal(dataset):

    df1 = sylhet_main
    df2 = dataset

    df = df1.join(df2.set_index('External_ID'), on='External_ID', how = 'left')
    df = df.drop(columns=["Contents"], axis = 1)
    df['contents'] = df['contents'].fillna("Null")
    return df


def errors(dataset, dname):

    dName = str(dataset)

    if len(dataset) == len(sylhet_main):

        CER = []
        WER = []

        dataset['contents'] = dataset['contents'].replace(["<>"], "")

        k = 1
        for i, j in zip(sylhet_main['Contents'],dataset['contents']):
            # print("{} -->", k)
            # print("main: {}",i)
            # print("\n")
            # print("inference: {}",j)
            # print("**************************\n")
            WER.append(wer(str(i), str(j)))
            k += 1


        for i, j in zip(sylhet_main['Contents'],dataset['contents']):
            CER.append(cer(str(i), str(j)))


        sylhet_main[f"CER ({dname})"] = CER
        sylhet_main[f"WER ({dname})"] = WER

    else:
        print("In\n")
        dataset = make_equal(dataset)
        errors(dataset,dname)



    return sylhet_main

# %%
df = errors(sylhet_b_whisper, 'B_Whisper')
df
# Out:
#                          External_ID  \
# 0                 rec_01_audio_1.wav
# 1                 rec_01_audio_3.wav
# 2                 rec_01_audio_4.wav
# 3                 rec_01_audio_5.wav
# 4                 rec_01_audio_6.wav
# ..                               ...
# 617   rec_45_big_audio_2_chunk_0.wav
# 618           rec_45_big_audio_5.wav
# 619           rec_45_big_audio_6.wav
# 620   rec_45_big_audio_8_chunk_0.wav
# 621  rec_45_big_audio_13_chunk_1.wav
#
#                                               Contents  CER (B_Whisper)  \
# 0    <> ডিউটি খরি, ডিউটি টু বাড়িত। আর তো <> আর সবকি...         1.055172
# 1    করিয়া তারপরে রেস্ট নিলাম কিছুক্ষন, রেস্ট নেওয়া...         0.735135
# 2    আট ঘন্টার ডিউটি পরে প্রতিদিনই। এইরকম ভাবে চেঞ্...         0.848101
# 3    কিরকম লাগে আমরা ছাত্র-ছাত্রীরা, স্যাররা? অনেক ...         0.785340
# 4    ডিউটিটা করতে খুব ভালা লাগে, সবকিছু মিলায়া খুব ...         0.816176
# ..                                                 ...              ...
# 617  আস্তে, আস্তে তো ওলাখান যার, যার। ফরে এখদিন এখ ...         0.766571
# 618  ফড়ার খেত্রে তখন তারারে ডায়রি লেখিয়া দেওয়া অয়, ...         0.744526
# 619  চেষ্টা খরি, ইসময় ফয়লা ফরীক্কা। ইটার ফরীক্কা আম...         0.779221
# 620  নায়কর বাফে ওইলো গিয়া ইসময় জমিদারোর সেরেস্তা কি...         0.729825
# 621  কুনু সন্তান আছিল না, নিঃসন্তান। এতো নিঃসন্তান ...         1.236111
#
#      WER (B_Whisper)
# 0           1.000000
# 1           1.000000
# 2           1.000000
# 3           1.000000
# 4           1.000000
# ..               ...
# 617         0.968750
# 618         0.980769
# 619         1.000000
# 620         0.981481
# 621         1.458333
#
# [622 rows x 4 columns]

# %%
metrics = {}


Avg_CER_b_whis = np.mean(df["CER (B_Whisper)"])
Avg_WER_b_whis = np.mean(df["WER (B_Whisper)"])

metrics["B_Whisper"] = f"Avg_WER : {Avg_WER_b_whis} | Avg_CER : {Avg_CER_b_whis}"

metrics
# Out:
# {'B_Whisper': 'Avg_WER : 1.6560954533017258 | Avg_CER : 2.6036372963031753'}
