# %%
pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 40.4 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.3 rapidfuzz-3.6.1

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
import os
import librosa
from tqdm import tqdm
from glob import glob
import pandas as pd
import numpy as np

# %%
from jiwer import wer, cer

# %%
habiganj_main = pd.read_excel('/content/drive/MyDrive/Habiganj_Audio/Habiganj_Data.xlsx')
habiganj_main
# Out:
#       Unnamed: 0    Original               External_ID  \
# 0              1  rec_01.wav        rec_01_audio_0.wav
# 1              2  rec_01.wav        rec_01_audio_1.wav
# 2              3  rec_01.wav        rec_01_audio_2.wav
# 3              4  rec_01.wav        rec_01_audio_3.wav
# 4              5  rec_01.wav        rec_01_audio_4.wav
# ...          ...         ...                       ...
# 1179        1180  rec_34.wav       rec_34_audio_17.wav
# 1180        1181  rec_34.wav       rec_34_audio_18.wav
# 1181        1182  rec_34.wav       rec_34_audio_19.wav
# 1182        1183  rec_34.wav       rec_34_audio_20.wav
# 1183        1184  rec_34.wav  rec_34_small_audio_0.wav
#
#                         Annotator  \
# 0         shah89@student.sust.edu
# 1         shah89@student.sust.edu
# 2         shah89@student.sust.edu
# 3         shah89@student.sust.edu
# 4         shah89@student.sust.edu
# ...                           ...
# 1179  sabrinayesminreya@gmail.com
# 1180  sabrinayesminreya@gmail.com
# 1181  sabrinayesminreya@gmail.com
# 1182  sabrinayesminreya@gmail.com
# 1183  sabrinayesminreya@gmail.com
#
#                                                Contents  District  Time
# 0     আইলাম তোমরার সাতে মাতবার লাইগা। বন্দ খর। সুফিয়...  Habiganj   524
# 1     না এরা দিতো না, এরা হুজুর মানুষ। কেরে দিতো না?...  Habiganj   295
# 2     <> ছেলে সামলানি লাগে। তে ফুলা কিতা অখনোই সামলা...  Habiganj   207
# 3     ইখানো তো মনো খর খাজ, অন্য খাজ তো খরন লাগে না, ...  Habiganj   668
# 4     বাফের বাইত আইলে রিল্যাক্স, যেবালা ইচ্ছা ইবালা ...  Habiganj   149
# ...                                                 ...       ...   ...
# 1179  টিক আছেনি? টিক আছে৷ আসলে <> আমরা ওইরা গেছিগা৷ ...  Habiganj     0
# 1180  ফ্যাচ লাগি যায়রেবো, ফ্যাচ লাগি যায়। <> আইচ্ছা ...  Habiganj     0
# 1181    ইটা খেটা যাইতাছে? ওবা, আও না। দুরু মিয়া, আও। <>  Habiganj     0
# 1182                ইটা <> বালা না। না ইটা <> তে খালকু।  Habiganj     0
# 1183                             <> ইটা নাইলে খাটি দেও।  Habiganj     0
#
# [1184 rows x 7 columns]

# %%
habiganj_main.columns
# Out:
# Index(['Unnamed: 0', 'Original', 'External_ID', 'Annotator', 'Contents',
#        'District', 'Time'],
#       dtype='object')

# %%
habiganj_main = habiganj_main.drop(labels = ['Unnamed: 0','Original','Annotator','District','Time'], axis = 1)
habiganj_main
# Out:
#                    External_ID  \
# 0           rec_01_audio_0.wav
# 1           rec_01_audio_1.wav
# 2           rec_01_audio_2.wav
# 3           rec_01_audio_3.wav
# 4           rec_01_audio_4.wav
# ...                        ...
# 1179       rec_34_audio_17.wav
# 1180       rec_34_audio_18.wav
# 1181       rec_34_audio_19.wav
# 1182       rec_34_audio_20.wav
# 1183  rec_34_small_audio_0.wav
#
#                                                Contents
# 0     আইলাম তোমরার সাতে মাতবার লাইগা। বন্দ খর। সুফিয়...
# 1     না এরা দিতো না, এরা হুজুর মানুষ। কেরে দিতো না?...
# 2     <> ছেলে সামলানি লাগে। তে ফুলা কিতা অখনোই সামলা...
# 3     ইখানো তো মনো খর খাজ, অন্য খাজ তো খরন লাগে না, ...
# 4     বাফের বাইত আইলে রিল্যাক্স, যেবালা ইচ্ছা ইবালা ...
# ...                                                 ...
# 1179  টিক আছেনি? টিক আছে৷ আসলে <> আমরা ওইরা গেছিগা৷ ...
# 1180  ফ্যাচ লাগি যায়রেবো, ফ্যাচ লাগি যায়। <> আইচ্ছা ...
# 1181    ইটা খেটা যাইতাছে? ওবা, আও না। দুরু মিয়া, আও। <>
# 1182                ইটা <> বালা না। না ইটা <> তে খালকু।
# 1183                             <> ইটা নাইলে খাটি দেও।
#
# [1184 rows x 2 columns]

# %%
len(habiganj_main)
# Out:
# 1184

# %%
habiganj_b_wav2vec2 = pd.read_csv('/content/drive/MyDrive/Habiganj_Audio/Bangla_Wav2vec2/Bangla-wav2vec2-habiganj-inference.csv')
habiganj_b_wav2vec2
# Out:
#       Unnamed: 0          External_ID  \
# 0              0   rec_06_audio_8.wav
# 1              1   rec_06_audio_6.wav
# 2              2   rec_06_audio_0.wav
# 3              3   rec_06_audio_5.wav
# 4              4   rec_06_audio_3.wav
# ...          ...                  ...
# 1179        1179  rec_05_audio_39.wav
# 1180        1180  rec_05_audio_38.wav
# 1181        1181  rec_05_audio_40.wav
# 1182        1182   rec_06_audio_7.wav
# 1183        1183   rec_06_audio_4.wav
#
#                                                Contents
# 0                                                    <>
# 1                                                    <>
# 2     ড়॥়‚দ‚ড় ৰউড়lড়য়নফ়‚aড়য়পড়াটয়ঁদ‚অগয়নঙlআয়জঝরৎফড়ঊঅড়...
# 3     ঊঅড় অফউড় ঝফড়ই অয়নফড় উঝঅlড়lইঅড়ঃফ‚ফড়—‚টaৎঊআঁ‚ড়lঅ...
# 4     lঊaঊয়নফংফউড়টঅঊগয়নড়পজউধজড়ঊa‚ গইৰঁঊফঊড়ঘজইaগঁ‚ঙনফ...
# ...                                                 ...
# 1179                                                 <>
# 1180                                                 <>
# 1181                                                 <>
# 1182                                                 <>
# 1183                                                 <>
#
# [1184 rows x 3 columns]

# %%
len(habiganj_b_wav2vec2)
# Out:
# 1184

# %%
def make_equal(dataset):

    df1 = habiganj_main
    df2 = dataset

    df = df1.join(df2.set_index('External_ID'), on='External_ID', how = 'left')
    df = df.drop(columns=["Contents"], axis = 1)
    df['Contents'] = df['Contents'].fillna("Null")
    return df


def errors(dataset, dname):

    dName = str(dataset)

    if len(dataset) == len(habiganj_main):

        CER = []
        WER = []

        dataset['Contents'] = dataset['Contents'].replace(["<>"], "")

        k = 1
        for i, j in zip(habiganj_main['Contents'],dataset['Contents']):
            # print("{} -->", k)
            # print("main: {}",i)
            # print("\n")
            # print("inference: {}",j)
            # print("**************************\n")
            WER.append(wer(str(i), str(j)))
            k += 1


        for i, j in zip(habiganj_main['Contents'],dataset['Contents']):
            CER.append(cer(str(i), str(j)))


        habiganj_main[f"CER ({dname})"] = CER
        habiganj_main[f"WER ({dname})"] = WER

    else:
        print("In\n")
        dataset = make_equal(dataset)
        errors(dataset,dname)



    return habiganj_main

# %%
df = errors(habiganj_b_wav2vec2, 'B_Wav2vec2')
df
# Out:
#                    External_ID  \
# 0           rec_01_audio_0.wav
# 1           rec_01_audio_1.wav
# 2           rec_01_audio_2.wav
# 3           rec_01_audio_3.wav
# 4           rec_01_audio_4.wav
# ...                        ...
# 1179       rec_34_audio_17.wav
# 1180       rec_34_audio_18.wav
# 1181       rec_34_audio_19.wav
# 1182       rec_34_audio_20.wav
# 1183  rec_34_small_audio_0.wav
#
#                                                Contents  CER (B_Wav2vec2)  \
# 0     আইলাম তোমরার সাতে মাতবার লাইগা। বন্দ খর। সুফিয়...          1.000000
# 1     না এরা দিতো না, এরা হুজুর মানুষ। কেরে দিতো না?...          1.000000
# 2     <> ছেলে সামলানি লাগে। তে ফুলা কিতা অখনোই সামলা...          0.943723
# 3     ইখানো তো মনো খর খাজ, অন্য খাজ তো খরন লাগে না, ...          0.913580
# 4     বাফের বাইত আইলে রিল্যাক্স, যেবালা ইচ্ছা ইবালা ...          0.952381
# ...                                                 ...               ...
# 1179  টিক আছেনি? টিক আছে৷ আসলে <> আমরা ওইরা গেছিগা৷ ...          1.000000
# 1180  ফ্যাচ লাগি যায়রেবো, ফ্যাচ লাগি যায়। <> আইচ্ছা ...          1.000000
# 1181    ইটা খেটা যাইতাছে? ওবা, আও না। দুরু মিয়া, আও। <>          1.000000
# 1182                ইটা <> বালা না। না ইটা <> তে খালকু।          1.000000
# 1183                             <> ইটা নাইলে খাটি দেও।          1.000000
#
#       WER (B_Wav2vec2)
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  1.0
# 4                  1.0
# ...                ...
# 1179               1.0
# 1180               1.0
# 1181               1.0
# 1182               1.0
# 1183               1.0
#
# [1184 rows x 4 columns]

# %%
metrics = {}


Avg_CER_b_wav2vec2 = np.mean(df["CER (B_Wav2vec2)"])
Avg_WER_b_wav2vec2 = np.mean(df["WER (B_Wav2vec2)"])

metrics["B_Wav2vec2"] = f"Avg_WER : {Avg_WER_b_wav2vec2} | Avg_CER : {Avg_CER_b_wav2vec2}"

metrics
# Out:
# {'B_Wav2vec2': 'Avg_WER : 1.0046452702702702 | Avg_CER : 1.6052958214475288'}
