# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
data_dir = '/content/drive/MyDrive/Habiganj_Audio/all_audios/'

# %%
# !pip install audiosegment
import audiosegment
# Out:
# Collecting audiosegment
#   Downloading audiosegment-0.23.0-py3-none-any.whl (34 kB)
# Collecting pydub (from audiosegment)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting webrtcvad (from audiosegment)
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from audiosegment) (1.23.5)
# Building wheels for collected packages: webrtcvad
#   Building wheel for webrtcvad (setup.py) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp310-cp310-linux_x86_64.whl size=73463 sha256=260de71c40123bcbe13d9c68bcc1eb811f7c0e5b222a5259c67152fc59a38936
#   Stored in directory: /root/.cache/pip/wheels/2a/2b/84/ac7bacfe8c68a87c1ee3dd3c66818a54c71599abf308e8eb35
# Successfully built webrtcvad
# Installing collected packages: webrtcvad, pydub, audiosegment
# Successfully installed audiosegment-0.23.0 pydub-0.25.1 webrtcvad-2.0.10

# %%
import audiosegment
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()

# %%
x = os.listdir(data_dir)
x
# Out:
# ['rec_06_audio_8.wav',
#  'rec_06_audio_6.wav',
#  'rec_06_audio_0.wav',
#  'rec_06_audio_5.wav',
#  'rec_06_audio_3.wav',
#  'rec_06_audio_2.wav',
#  'rec_06_audio_1.wav',
#  'rec_06_audio_22.wav',
#  'rec_06_audio_14.wav',
#  'rec_06_audio_21.wav',
#  'rec_06_audio_13.wav',
#  'rec_06_audio_16.wav',
#  'rec_06_audio_10.wav',
#  'rec_06_audio_17.wav',
#  'rec_06_audio_19.wav',
#  'rec_06_audio_11.wav',
#  'rec_06_audio_23.wav',
#  'rec_06_audio_12.wav',
#  'rec_06_audio_18.wav',
#  'rec_06_audio_15.wav',
#  'rec_06_audio_20.wav',
#  'rec_06_audio_9.wav',
#  'rec_06_audio_35.wav',
#  'rec_06_audio_33.wav',
#  'rec_06_audio_30.wav',
#  'rec_06_audio_34.wav',
#  'rec_06_audio_29.wav',
#  'rec_06_audio_36.wav',
#  'rec_06_audio_25.wav',
#  'rec_06_audio_38.wav',
#  'rec_06_audio_31.wav',
#  'rec_06_audio_27.wav',
#  'rec_06_audio_28.wav',
#  'rec_06_audio_37.wav',
#  'rec_06_audio_26.wav',
#  'rec_06_audio_24.wav',
#  'rec_06_audio_32.wav',
#  'rec_06_audio_48.wav',
#  'rec_06_audio_44.wav',
#  'rec_06_audio_45.wav',
#  'rec_06_audio_46.wav',
#  'rec_06_audio_51.wav',
#  'rec_06_audio_43.wav',
#  'rec_06_audio_47.wav',
#  'rec_06_audio_40.wav',
#  'rec_06_audio_41.wav',
#  'rec_06_audio_49.wav',
#  'rec_06_audio_50.wav',
#  'rec_06_audio_42.wav',
#  'rec_06_audio_39.wav',
#  'rec_06_audio_66.wav',
#  'rec_06_audio_56.wav',
#  'rec_06_audio_60.wav',
#  'rec_06_audio_55.wav',
#  'rec_06_audio_62.wav',
#  'rec_06_audio_58.wav',
#  'rec_06_audio_65.wav',
#  'rec_06_audio_54.wav',
#  'rec_06_audio_64.wav',
#  'rec_06_audio_57.wav',
#  'rec_06_audio_63.wav',
#  'rec_06_audio_61.wav',
#  'rec_06_audio_59.wav',
#  'rec_06_audio_52.wav',
#  'rec_06_audio_53.wav',
#  'rec_06_audio_68.wav',
#  'rec_06_audio_67.wav',
#  'rec_06_small_audio_0.wav',
#  'rec_07_audio_2.wav',
#  'rec_07_audio_16.wav',
#  'rec_07_audio_0.wav',
#  'rec_07_audio_15.wav',
#  'rec_07_audio_13.wav',
#  'rec_07_audio_1.wav',
#  'rec_07_audio_14.wav',
#  'rec_07_audio_4.wav',
#  'rec_07_audio_10.wav',
#  'rec_07_audio_8.wav',
#  'rec_07_audio_7.wav',
#  'rec_07_audio_11.wav',
#  'rec_07_audio_12.wav',
#  'rec_07_audio_5.wav',
#  'rec_07_audio_9.wav',
#  'rec_07_audio_3.wav',
#  'rec_07_audio_6.wav',
#  'rec_07_audio_21.wav',
#  'rec_07_audio_25.wav',
#  'rec_07_audio_22.wav',
#  'rec_07_audio_24.wav',
#  'rec_07_audio_20.wav',
#  'rec_07_audio_19.wav',
#  'rec_07_audio_26.wav',
#  'rec_07_audio_18.wav',
#  'rec_07_audio_17.wav',
#  'rec_07_audio_23.wav',
#  'rec_07_small_audio_0.wav',
#  'rec_08_audio_1.wav',
#  'rec_08_audio_0.wav',
#  'rec_08_audio_4.wav',
#  'rec_08_audio_5.wav',
#  'rec_08_audio_11.wav',
#  'rec_08_audio_14.wav',
#  'rec_08_audio_9.wav',
#  'rec_08_audio_2.wav',
#  'rec_08_audio_17.wav',
#  'rec_08_audio_10.wav',
#  'rec_08_audio_15.wav',
#  'rec_08_audio_12.wav',
#  'rec_08_audio_6.wav',
#  'rec_08_audio_3.wav',
#  'rec_08_audio_16.wav',
#  'rec_08_audio_13.wav',
#  'rec_08_audio_7.wav',
#  'rec_08_audio_8.wav',
#  'rec_08_audio_24.wav',
#  'rec_08_audio_18.wav',
#  'rec_08_audio_26.wav',
#  'rec_08_audio_25.wav',
#  'rec_08_audio_19.wav',
#  'rec_08_audio_21.wav',
#  'rec_08_audio_28.wav',
#  'rec_08_audio_23.wav',
#  'rec_08_audio_27.wav',
#  'rec_08_audio_22.wav',
#  'rec_08_audio_20.wav',
#  'rec_08_small_audio_0.wav',
#  'rec_09_audio_3.wav',
#  'rec_09_audio_2.wav',
#  'rec_09_audio_10.wav',
#  'rec_09_audio_9.wav',
#  'rec_09_audio_0.wav',
#  'rec_09_audio_4.wav',
#  'rec_09_audio_1.wav',
#  'rec_09_audio_8.wav',
#  'rec_09_audio_5.wav',
#  'rec_09_audio_7.wav',
#  'rec_09_audio_6.wav',
#  'rec_09_audio_14.wav',
#  'rec_09_audio_26.wav',
#  'rec_09_audio_25.wav',
#  'rec_09_audio_11.wav',
#  'rec_09_audio_23.wav',
#  'rec_09_audio_20.wav',
#  'rec_09_audio_29.wav',
#  'rec_09_audio_16.wav',
#  'rec_09_audio_13.wav',
#  'rec_09_audio_17.wav',
#  'rec_09_audio_28.wav',
#  'rec_09_audio_12.wav',
#  'rec_09_audio_24.wav',
#  'rec_09_audio_15.wav',
#  'rec_09_audio_27.wav',
#  'rec_09_audio_21.wav',
#  'rec_09_audio_18.wav',
#  'rec_09_audio_19.wav',
#  'rec_09_audio_22.wav',
#  'rec_09_audio_42.wav',
#  'rec_09_audio_37.wav',
#  'rec_09_audio_33.wav',
#  'rec_09_audio_46.wav',
#  'rec_09_audio_47.wav',
#  'rec_09_audio_35.wav',
#  'rec_09_audio_44.wav',
#  'rec_09_audio_36.wav',
#  'rec_09_audio_32.wav',
#  'rec_09_audio_40.wav',
#  'rec_09_audio_41.wav',
#  'rec_09_audio_39.wav',
#  'rec_09_audio_31.wav',
#  'rec_09_audio_34.wav',
#  'rec_09_audio_43.wav',
#  'rec_09_audio_38.wav',
#  'rec_09_audio_30.wav',
#  'rec_09_audio_45.wav',
#  'rec_09_audio_48.wav',
#  'rec_09_small_audio_0.wav',
#  'rec_10_audio_0.wav',
#  'rec_10_audio_13.wav',
#  'rec_10_audio_1.wav',
#  'rec_10_audio_3.wav',
#  'rec_10_audio_4.wav',
#  'rec_10_audio_14.wav',
#  'rec_10_small_audio_0.wav',
#  'rec_10_audio_11.wav',
#  'rec_10_audio_9.wav',
#  'rec_10_audio_5.wav',
#  'rec_10_audio_7.wav',
#  'rec_10_audio_12.wav',
#  'rec_10_audio_2.wav',
#  'rec_10_audio_8.wav',
#  'rec_10_audio_6.wav',
#  'rec_10_audio_15.wav',
#  'rec_10_audio_10.wav',
#  'rec_11_audio_0.wav',
#  'rec_11_audio_12.wav',
#  'rec_11_audio_6.wav',
#  'rec_11_audio_4.wav',
#  'rec_11_audio_7.wav',
#  'rec_11_audio_13.wav',
#  'rec_11_audio_10.wav',
#  'rec_11_audio_5.wav',
#  'rec_11_audio_14.wav',
#  'rec_11_audio_17.wav',
#  'rec_11_audio_2.wav',
#  'rec_11_audio_3.wav',
#  'rec_11_audio_8.wav',
#  'rec_11_audio_1.wav',
#  'rec_11_audio_16.wav',
#  'rec_11_audio_11.wav',
#  'rec_11_audio_9.wav',
#  'rec_11_audio_19.wav',
#  'rec_11_audio_15.wav',
#  'rec_11_audio_18.wav',
#  'rec_11_audio_23.wav',
#  'rec_11_audio_21.wav',
#  'rec_11_audio_22.wav',
#  'rec_11_audio_24.wav',
#  'rec_11_audio_20.wav',
#  'rec_12_audio_8.wav',
#  'rec_12_audio_6.wav',
#  'rec_12_audio_1.wav',
#  'rec_12_audio_10.wav',
#  'rec_12_audio_3.wav',
#  'rec_12_audio_5.wav',
#  'rec_12_audio_0.wav',
#  'rec_12_audio_14.wav',
#  'rec_12_audio_2.wav',
#  'rec_12_audio_4.wav',
#  'rec_12_audio_11.wav',
#  'rec_12_audio_7.wav',
#  'rec_12_audio_12.wav',
#  'rec_12_audio_13.wav',
#  'rec_12_audio_9.wav',
#  'rec_12_audio_31.wav',
#  'rec_12_audio_21.wav',
#  'rec_12_audio_32.wav',
#  'rec_12_audio_28.wav',
#  'rec_12_audio_16.wav',
#  'rec_12_small_audio_0.wav',
#  'rec_12_audio_29.wav',
#  'rec_12_audio_19.wav',
#  'rec_12_audio_17.wav',
#  'rec_12_audio_24.wav',
#  'rec_12_audio_23.wav',
#  'rec_12_audio_33.wav',
#  'rec_12_audio_30.wav',
#  'rec_12_audio_20.wav',
#  'rec_12_audio_22.wav',
#  'rec_12_audio_15.wav',
#  'rec_12_audio_26.wav',
#  'rec_12_audio_27.wav',
#  'rec_12_audio_25.wav',
#  'rec_12_audio_18.wav',
#  'rec_13_audio_5.wav',
#  'rec_13_audio_13.wav',
#  'rec_13_audio_17.wav',
#  'rec_13_audio_12.wav',
#  'rec_13_audio_15.wav',
#  'rec_13_audio_2.wav',
#  'rec_13_audio_3.wav',
#  'rec_13_audio_16.wav',
#  'rec_13_audio_6.wav',
#  'rec_13_audio_1.wav',
#  'rec_13_audio_4.wav',
#  'rec_13_audio_19.wav',
#  'rec_13_audio_9.wav',
#  'rec_13_audio_7.wav',
#  'rec_13_audio_10.wav',
#  'rec_13_audio_11.wav',
#  'rec_13_audio_18.wav',
#  'rec_13_audio_8.wav',
#  'rec_13_audio_0.wav',
#  'rec_13_audio_14.wav',
#  'rec_13_audio_28.wav',
#  'rec_13_audio_33.wav',
#  'rec_13_audio_40.wav',
#  'rec_13_audio_21.wav',
#  'rec_13_audio_39.wav',
#  'rec_13_audio_32.wav',
#  'rec_13_audio_20.wav',
#  'rec_13_audio_38.wav',
#  'rec_13_audio_25.wav',
#  'rec_13_audio_30.wav',
#  'rec_13_audio_26.wav',
#  'rec_13_audio_22.wav',
#  'rec_13_audio_23.wav',
#  'rec_13_audio_31.wav',
#  'rec_13_audio_29.wav',
#  'rec_13_audio_34.wav',
#  'rec_13_audio_24.wav',
#  'rec_13_audio_36.wav',
#  'rec_13_audio_37.wav',
#  'rec_13_audio_35.wav',
#  'rec_13_audio_27.wav',
#  'rec_13_small_audio_0.wav',
#  'rec_14_audio_0.wav',
#  'rec_14_audio_10.wav',
#  'rec_14_audio_11.wav',
#  'rec_14_audio_18.wav',
#  'rec_14_audio_9.wav',
#  'rec_14_audio_15.wav',
#  'rec_14_audio_3.wav',
#  'rec_14_audio_14.wav',
#  'rec_14_audio_5.wav',
#  'rec_14_audio_2.wav',
#  'rec_14_audio_4.wav',
#  'rec_14_audio_12.wav',
#  'rec_14_audio_8.wav',
#  'rec_14_audio_13.wav',
#  'rec_14_audio_19.wav',
#  'rec_14_audio_16.wav',
#  'rec_14_audio_1.wav',
#  'rec_14_audio_17.wav',
#  'rec_14_audio_6.wav',
#  'rec_14_audio_7.wav',
#  'rec_14_audio_31.wav',
#  'rec_14_audio_24.wav',
#  'rec_14_audio_20.wav',
#  'rec_14_audio_33.wav',
#  'rec_14_audio_26.wav',
#  'rec_14_audio_37.wav',
#  'rec_14_audio_23.wav',
#  'rec_14_audio_27.wav',
#  'rec_14_audio_36.wav',
#  'rec_14_audio_28.wav',
#  'rec_14_audio_29.wav',
#  'rec_14_audio_21.wav',
#  'rec_14_audio_32.wav',
#  'rec_14_audio_34.wav',
#  'rec_14_audio_30.wav',
#  'rec_14_audio_22.wav',
#  'rec_14_audio_35.wav',
#  'rec_14_audio_38.wav',
#  'rec_14_audio_25.wav',
#  'rec_15_audio_1.wav',
#  'rec_15_audio_6.wav',
#  'rec_15_audio_14.wav',
#  'rec_15_audio_12.wav',
#  'rec_15_audio_15.wav',
#  'rec_15_audio_4.wav',
#  'rec_15_audio_10.wav',
#  'rec_15_audio_7.wav',
#  'rec_15_audio_0.wav',
#  'rec_15_audio_9.wav',
#  'rec_15_audio_11.wav',
#  'rec_15_audio_8.wav',
#  'rec_15_audio_3.wav',
#  'rec_15_audio_5.wav',
#  'rec_15_audio_13.wav',
#  'rec_15_audio_2.wav',
#  'rec_15_audio_16.wav',
#  'rec_15_small_audio_0.wav',
#  'rec_15_audio_18.wav',
#  'rec_15_audio_17.wav',
#  'rec_16_audio_2.wav',
#  'rec_16_audio_3.wav',
#  'rec_16_audio_0.wav',
#  'rec_16_audio_1.wav',
#  'rec_16_audio_4.wav',
#  'rec_16_audio_8.wav',
#  'rec_16_audio_6.wav',
#  'rec_16_audio_5.wav',
#  'rec_16_audio_7.wav',
#  'rec_17_audio_2.wav',
#  'rec_17_audio_14.wav',
#  'rec_17_audio_9.wav',
#  'rec_17_audio_15.wav',
#  'rec_17_audio_4.wav',
#  'rec_17_audio_3.wav',
#  'rec_17_audio_6.wav',
#  'rec_17_audio_16.wav',
#  'rec_17_audio_1.wav',
#  'rec_17_audio_5.wav',
#  'rec_17_audio_8.wav',
#  'rec_17_audio_0.wav',
#  'rec_17_audio_11.wav',
#  'rec_17_audio_10.wav',
#  'rec_17_audio_13.wav',
#  'rec_17_audio_7.wav',
#  'rec_17_audio_12.wav',
#  'rec_17_audio_19.wav',
#  'rec_17_audio_29.wav',
#  'rec_17_audio_25.wav',
#  'rec_17_audio_23.wav',
#  'rec_17_audio_22.wav',
#  'rec_17_audio_32.wav',
#  'rec_17_audio_27.wav',
#  'rec_17_audio_24.wav',
#  'rec_17_audio_31.wav',
#  'rec_17_audio_34.wav',
#  'rec_17_audio_21.wav',
#  'rec_17_audio_33.wav',
#  'rec_17_audio_17.wav',
#  'rec_17_audio_30.wav',
#  'rec_17_audio_26.wav',
#  'rec_17_audio_18.wav',
#  'rec_17_audio_28.wav',
#  'rec_17_audio_20.wav',
#  'rec_17_audio_35.wav',
#  'rec_17_audio_38.wav',
#  'rec_17_audio_43.wav',
#  'rec_17_small_audio_0.wav',
#  'rec_17_audio_41.wav',
#  'rec_17_audio_39.wav',
#  'rec_17_audio_36.wav',
#  'rec_17_audio_42.wav',
#  'rec_17_audio_40.wav',
#  'rec_17_audio_37.wav',
#  'rec_18_audio_1.wav',
#  'rec_18_audio_2.wav',
#  'rec_18_audio_0.wav',
#  'rec_18_audio_11.wav',
#  'rec_18_audio_6.wav',
#  'rec_18_audio_21.wav',
#  'rec_18_audio_15.wav',
#  'rec_18_audio_20.wav',
#  'rec_18_audio_18.wav',
#  'rec_18_audio_17.wav',
#  'rec_18_audio_12.wav',
#  'rec_18_audio_7.wav',
#  'rec_18_audio_8.wav',
#  'rec_18_audio_16.wav',
#  'rec_18_audio_9.wav',
#  'rec_18_audio_5.wav',
#  'rec_18_audio_13.wav',
#  'rec_18_audio_26.wav',
#  'rec_18_audio_4.wav',
#  'rec_18_audio_22.wav',
#  'rec_18_audio_14.wav',
#  'rec_18_audio_10.wav',
#  'rec_18_audio_23.wav',
#  'rec_18_audio_19.wav',
#  'rec_18_audio_3.wav',
#  'rec_18_audio_24.wav',
#  'rec_18_audio_25.wav',
#  'rec_18_audio_34.wav',
#  'rec_18_audio_36.wav',
#  'rec_18_audio_29.wav',
#  'rec_18_audio_32.wav',
#  'rec_18_audio_38.wav',
#  'rec_18_audio_28.wav',
#  'rec_18_audio_27.wav',
#  'rec_18_audio_42.wav',
#  'rec_18_audio_48.wav',
#  'rec_18_audio_35.wav',
#  'rec_18_audio_31.wav',
#  'rec_18_audio_46.wav',
#  'rec_18_audio_40.wav',
#  'rec_18_audio_47.wav',
#  'rec_18_audio_43.wav',
#  'rec_18_audio_33.wav',
#  'rec_18_audio_37.wav',
#  'rec_18_audio_45.wav',
#  'rec_18_audio_41.wav',
#  'rec_18_audio_30.wav',
#  'rec_18_audio_39.wav',
#  'rec_18_audio_44.wav',
#  'rec_19_audio_0.wav',
#  'rec_19_audio_4.wav',
#  'rec_19_audio_3.wav',
#  'rec_19_audio_2.wav',
#  'rec_19_audio_9.wav',
#  'rec_19_audio_7.wav',
#  'rec_19_audio_5.wav',
#  'rec_19_audio_6.wav',
#  'rec_19_audio_1.wav',
#  'rec_19_audio_8.wav',
#  'rec_19_audio_23.wav',
#  'rec_19_audio_33.wav',
#  'rec_19_audio_18.wav',
#  'rec_19_audio_19.wav',
#  'rec_19_audio_11.wav',
#  'rec_19_audio_30.wav',
#  'rec_19_audio_31.wav',
#  'rec_19_audio_12.wav',
#  'rec_19_audio_14.wav',
#  'rec_19_audio_16.wav',
#  'rec_19_audio_15.wav',
#  'rec_19_audio_13.wav',
#  'rec_19_audio_17.wav',
#  'rec_19_audio_10.wav',
#  'rec_19_audio_28.wav',
#  'rec_19_audio_20.wav',
#  'rec_19_audio_34.wav',
#  'rec_19_audio_22.wav',
#  'rec_19_audio_29.wav',
#  'rec_19_audio_24.wav',
#  'rec_19_audio_27.wav',
#  'rec_19_audio_26.wav',
#  'rec_19_audio_21.wav',
#  'rec_19_audio_32.wav',
#  'rec_19_audio_25.wav',
#  'rec_19_small_audio_0.wav',
#  'rec_19_audio_37.wav',
#  'rec_19_audio_35.wav',
#  'rec_19_audio_36.wav',
#  'rec_20_audio_9.wav',
#  'rec_20_audio_1.wav',
#  'rec_20_audio_3.wav',
#  'rec_20_audio_5.wav',
#  'rec_20_audio_0.wav',
#  'rec_20_audio_2.wav',
#  'rec_20_audio_4.wav',
#  'rec_20_audio_7.wav',
#  'rec_20_audio_10.wav',
#  'rec_20_audio_6.wav',
#  'rec_20_audio_8.wav',
#  'rec_20_audio_34.wav',
#  'rec_20_audio_12.wav',
#  'rec_20_audio_26.wav',
#  'rec_20_audio_30.wav',
#  'rec_20_audio_29.wav',
#  'rec_20_audio_33.wav',
#  'rec_20_audio_19.wav',
#  'rec_20_audio_17.wav',
#  'rec_20_audio_14.wav',
#  'rec_20_audio_32.wav',
#  'rec_20_audio_21.wav',
#  'rec_20_audio_16.wav',
#  'rec_20_audio_23.wav',
#  'rec_20_audio_24.wav',
#  'rec_20_audio_15.wav',
#  'rec_20_audio_28.wav',
#  'rec_20_audio_25.wav',
#  'rec_20_audio_11.wav',
#  'rec_20_audio_31.wav',
#  'rec_20_audio_27.wav',
#  'rec_20_audio_22.wav',
#  'rec_20_audio_18.wav',
#  'rec_20_audio_20.wav',
#  'rec_20_audio_13.wav',
#  'rec_20_audio_58.wav',
#  'rec_20_audio_40.wav',
#  'rec_20_audio_45.wav',
#  'rec_20_audio_46.wav',
#  'rec_20_audio_48.wav',
#  'rec_20_audio_44.wav',
#  'rec_20_audio_51.wav',
#  'rec_20_audio_42.wav',
#  'rec_20_audio_55.wav',
#  'rec_20_audio_56.wav',
#  'rec_20_audio_47.wav',
#  'rec_20_audio_38.wav',
#  'rec_20_audio_41.wav',
#  'rec_20_audio_36.wav',
#  'rec_20_audio_49.wav',
#  'rec_20_audio_52.wav',
#  'rec_20_audio_57.wav',
#  'rec_20_audio_53.wav',
#  'rec_20_audio_50.wav',
#  'rec_20_audio_37.wav',
#  'rec_20_audio_39.wav',
#  'rec_20_audio_43.wav',
#  'rec_20_audio_54.wav',
#  'rec_20_audio_35.wav',
#  'rec_20_audio_59.wav',
#  'rec_20_audio_60.wav',
#  'rec_21_audio_3.wav',
#  'rec_21_audio_12.wav',
#  'rec_21_audio_1.wav',
#  'rec_21_audio_13.wav',
#  'rec_21_audio_0.wav',
#  'rec_21_audio_14.wav',
#  'rec_21_audio_4.wav',
#  'rec_21_audio_19.wav',
#  'rec_21_audio_2.wav',
#  'rec_21_audio_7.wav',
#  'rec_21_audio_11.wav',
#  'rec_21_audio_16.wav',
#  'rec_21_audio_17.wav',
#  'rec_21_audio_6.wav',
#  'rec_21_audio_8.wav',
#  'rec_21_audio_18.wav',
#  'rec_21_audio_10.wav',
#  'rec_21_audio_15.wav',
#  'rec_21_audio_5.wav',
#  'rec_21_audio_9.wav',
#  'rec_21_audio_38.wav',
#  'rec_21_audio_37.wav',
#  'rec_21_audio_31.wav',
#  'rec_21_audio_20.wav',
#  'rec_21_audio_35.wav',
#  'rec_21_audio_26.wav',
#  'rec_21_audio_42.wav',
#  'rec_21_audio_25.wav',
#  'rec_21_audio_41.wav',
#  'rec_21_audio_43.wav',
#  'rec_21_audio_28.wav',
#  'rec_21_audio_36.wav',
#  'rec_21_audio_29.wav',
#  'rec_21_audio_27.wav',
#  'rec_21_audio_24.wav',
#  'rec_21_audio_34.wav',
#  'rec_21_audio_33.wav',
#  'rec_21_audio_32.wav',
#  'rec_21_audio_40.wav',
#  'rec_21_audio_39.wav',
#  'rec_21_audio_21.wav',
#  'rec_21_audio_45.wav',
#  'rec_21_audio_30.wav',
#  'rec_21_audio_23.wav',
#  'rec_21_audio_22.wav',
#  'rec_21_audio_44.wav',
#  'rec_21_audio_55.wav',
#  'rec_21_audio_50.wav',
#  'rec_21_audio_56.wav',
#  'rec_21_audio_46.wav',
#  'rec_21_audio_53.wav',
#  'rec_21_audio_54.wav',
#  'rec_21_audio_48.wav',
#  'rec_21_audio_52.wav',
#  'rec_21_audio_47.wav',
#  'rec_21_audio_51.wav',
#  'rec_21_audio_49.wav',
#  'rec_22_audio_0.wav',
#  'rec_22_audio_1.wav',
#  'rec_22_audio_2.wav',
#  'rec_22_audio_12.wav',
#  'rec_22_audio_6.wav',
#  'rec_22_audio_4.wav',
#  'rec_22_audio_11.wav',
#  'rec_22_audio_5.wav',
#  'rec_22_audio_9.wav',
#  'rec_22_audio_13.wav',
#  'rec_22_audio_7.wav',
#  'rec_22_audio_3.wav',
#  'rec_22_audio_8.wav',
#  'rec_22_audio_10.wav',
#  'rec_23_audio_1.wav',
#  'rec_23_big_audio_0.wav',
#  'rec_23_audio_0.wav',
#  'rec_23_audio_3.wav',
#  'rec_23_audio_4.wav',
#  'rec_23_audio_2.wav',
#  'rec_23_audio_19.wav',
#  'rec_23_audio_20.wav',
#  'rec_23_audio_9.wav',
#  'rec_23_audio_18.wav',
#  'rec_23_audio_17.wav',
#  'rec_23_audio_14.wav',
#  'rec_23_audio_6.wav',
#  'rec_23_audio_13.wav',
#  'rec_23_audio_7.wav',
#  'rec_23_audio_22.wav',
#  'rec_23_audio_8.wav',
#  'rec_23_audio_12.wav',
#  'rec_23_audio_15.wav',
#  'rec_23_audio_23.wav',
#  'rec_23_audio_21.wav',
#  'rec_23_audio_16.wav',
#  'rec_23_audio_11.wav',
#  'rec_23_audio_5.wav',
#  'rec_23_audio_24.wav',
#  'rec_23_audio_26.wav',
#  'rec_23_audio_10.wav',
#  'rec_23_audio_25.wav',
#  'rec_23_audio_28.wav',
#  'rec_23_audio_27.wav',
#  'rec_23_audio_29.wav',
#  'rec_24_audio_6.wav',
#  'rec_24_audio_13.wav',
#  'rec_24_audio_5.wav',
#  'rec_24_audio_0.wav',
#  'rec_24_audio_4.wav',
#  'rec_24_audio_1.wav',
#  'rec_24_audio_3.wav',
#  'rec_24_audio_11.wav',
#  'rec_24_audio_10.wav',
#  'rec_24_audio_9.wav',
#  'rec_24_audio_8.wav',
#  'rec_24_audio_12.wav',
#  'rec_24_audio_14.wav',
#  'rec_24_audio_2.wav',
#  'rec_24_audio_15.wav',
#  'rec_24_audio_7.wav',
#  'rec_24_audio_22.wav',
#  'rec_24_audio_29.wav',
#  'rec_24_audio_21.wav',
#  'rec_24_audio_28.wav',
#  'rec_24_audio_27.wav',
#  'rec_24_audio_30.wav',
#  'rec_24_audio_19.wav',
#  'rec_24_audio_20.wav',
#  'rec_24_audio_18.wav',
#  'rec_24_audio_16.wav',
#  'rec_24_audio_26.wav',
#  'rec_24_audio_17.wav',
#  'rec_24_audio_23.wav',
#  'rec_24_audio_25.wav',
#  'rec_24_audio_24.wav',
#  'rec_25_audio_2.wav',
#  'rec_25_audio_3.wav',
#  'rec_25_audio_0.wav',
#  'rec_25_audio_6.wav',
#  'rec_25_audio_5.wav',
#  'rec_25_audio_4.wav',
#  'rec_25_audio_1.wav',
#  'rec_25_audio_7.wav',
#  'rec_25_audio_20.wav',
#  'rec_25_audio_24.wav',
#  'rec_25_audio_16.wav',
#  'rec_25_audio_8.wav',
#  'rec_25_audio_25.wav',
#  'rec_25_audio_12.wav',
#  'rec_25_audio_11.wav',
#  'rec_25_audio_18.wav',
#  'rec_25_audio_26.wav',
#  'rec_25_audio_17.wav',
#  'rec_25_audio_14.wav',
#  'rec_25_audio_23.wav',
#  'rec_25_audio_28.wav',
#  'rec_25_audio_22.wav',
#  'rec_25_audio_9.wav',
#  'rec_25_audio_10.wav',
#  'rec_25_small_audio_0.wav',
#  'rec_25_audio_13.wav',
#  'rec_25_audio_21.wav',
#  'rec_25_audio_27.wav',
#  'rec_25_audio_19.wav',
#  'rec_25_audio_15.wav',
#  'rec_26_big_audio_0.wav',
#  'rec_26_audio_0.wav',
#  'rec_26_audio_3.wav',
#  'rec_26_audio_6.wav',
#  'rec_26_audio_18.wav',
#  'rec_26_audio_5.wav',
#  'rec_26_audio_15.wav',
#  'rec_26_audio_13.wav',
#  'rec_26_audio_24.wav',
#  'rec_26_audio_20.wav',
#  'rec_26_audio_17.wav',
#  'rec_26_audio_2.wav',
#  'rec_26_audio_7.wav',
#  'rec_26_audio_19.wav',
#  'rec_26_audio_9.wav',
#  'rec_26_audio_23.wav',
#  'rec_26_audio_8.wav',
#  'rec_26_audio_21.wav',
#  'rec_26_audio_22.wav',
#  'rec_26_audio_10.wav',
#  'rec_26_small_audio_0.wav',
#  'rec_26_audio_12.wav',
#  'rec_26_audio_4.wav',
#  'rec_26_audio_14.wav',
#  'rec_26_audio_16.wav',
#  'rec_26_audio_11.wav',
#  'rec_26_audio_1.wav',
#  'rec_26_audio_45.wav',
#  'rec_26_audio_27.wav',
#  'rec_26_audio_39.wav',
#  'rec_26_audio_33.wav',
#  'rec_26_audio_35.wav',
#  'rec_26_audio_44.wav',
#  'rec_26_audio_48.wav',
#  'rec_26_audio_40.wav',
#  'rec_26_audio_31.wav',
#  'rec_26_audio_29.wav',
#  'rec_26_audio_26.wav',
#  'rec_26_audio_49.wav',
#  'rec_26_audio_28.wav',
#  'rec_26_audio_38.wav',
#  'rec_26_audio_47.wav',
#  'rec_26_audio_37.wav',
#  'rec_26_audio_34.wav',
#  'rec_26_audio_36.wav',
#  'rec_26_audio_42.wav',
#  'rec_26_audio_43.wav',
#  'rec_26_audio_41.wav',
#  'rec_26_audio_25.wav',
#  'rec_26_audio_32.wav',
#  'rec_26_audio_30.wav',
#  'rec_26_audio_46.wav',
#  'rec_26_audio_53.wav',
#  'rec_26_small_audio_2.wav',
#  'rec_26_audio_54.wav',
#  'rec_26_audio_55.wav',
#  'rec_26_audio_50.wav',
#  'rec_26_audio_51.wav',
#  'rec_26_audio_52.wav',
#  'rec_27_big_audio_2.wav',
#  'rec_27_audio_15.wav',
#  'rec_27_audio_2.wav',
#  'rec_27_audio_20.wav',
#  'rec_27_audio_0.wav',
#  'rec_27_audio_13.wav',
#  'rec_27_audio_4.wav',
#  'rec_27_audio_9.wav',
#  'rec_27_big_audio_7.wav',
#  'rec_27_audio_5.wav',
#  'rec_27_audio_11.wav',
#  'rec_27_audio_17.wav',
#  'rec_27_audio_18.wav',
#  'rec_27_audio_1.wav',
#  'rec_27_audio_6.wav',
#  'rec_27_audio_7.wav',
#  'rec_27_audio_14.wav',
#  'rec_27_audio_16.wav',
#  'rec_27_audio_3.wav',
#  'rec_27_audio_8.wav',
#  'rec_27_audio_19.wav',
#  'rec_27_audio_12.wav',
#  'rec_27_audio_10.wav',
#  'rec_27_audio_27.wav',
#  'rec_27_small_audio_0.wav',
#  'rec_27_audio_22.wav',
#  'rec_27_audio_24.wav',
#  'rec_27_audio_25.wav',
#  'rec_27_audio_21.wav',
#  'rec_27_audio_26.wav',
#  'rec_27_audio_23.wav',
#  'rec_28_audio_0.wav',
#  'rec_28_audio_1.wav',
#  'rec_28_audio_21.wav',
#  'rec_28_audio_23.wav',
#  'rec_28_audio_12.wav',
#  'rec_28_audio_4.wav',
#  'rec_28_audio_8.wav',
#  'rec_28_audio_24.wav',
#  'rec_28_audio_17.wav',
#  'rec_28_audio_2.wav',
#  'rec_28_audio_7.wav',
#  'rec_28_audio_14.wav',
#  'rec_28_audio_18.wav',
#  'rec_28_audio_5.wav',
#  'rec_28_audio_19.wav',
#  'rec_28_audio_20.wav',
#  'rec_28_audio_15.wav',
#  'rec_28_audio_11.wav',
#  'rec_28_audio_6.wav',
#  'rec_28_small_audio_0.wav',
#  'rec_28_audio_22.wav',
#  'rec_28_audio_13.wav',
#  'rec_28_audio_3.wav',
#  'rec_28_audio_16.wav',
#  'rec_28_audio_25.wav',
#  'rec_28_audio_9.wav',
#  'rec_28_audio_10.wav',
#  'rec_28_audio_34.wav',
#  'rec_28_audio_31.wav',
#  'rec_28_audio_33.wav',
#  'rec_28_audio_32.wav',
#  'rec_28_audio_36.wav',
#  'rec_28_audio_30.wav',
#  'rec_28_audio_28.wav',
#  'rec_28_audio_38.wav',
#  'rec_28_audio_35.wav',
#  'rec_28_audio_29.wav',
#  'rec_28_audio_37.wav',
#  'rec_28_audio_26.wav',
#  'rec_28_audio_27.wav',
#  'rec_29_audio_7.wav',
#  'rec_29_audio_6.wav',
#  'rec_29_audio_5.wav',
#  'rec_29_audio_3.wav',
#  'rec_29_audio_1.wav',
#  'rec_29_audio_8.wav',
#  'rec_29_small_audio_0.wav',
#  'rec_29_audio_4.wav',
#  'rec_29_audio_2.wav',
#  'rec_29_audio_0.wav',
#  'rec_30_audio_0.wav',
#  'rec_30_audio_1.wav',
#  'rec_30_audio_5.wav',
#  'rec_30_audio_9.wav',
#  'rec_30_audio_12.wav',
#  'rec_30_audio_11.wav',
#  'rec_30_audio_2.wav',
#  'rec_30_audio_4.wav',
#  'rec_30_audio_8.wav',
#  'rec_30_audio_14.wav',
#  'rec_30_audio_13.wav',
#  'rec_30_audio_3.wav',
#  'rec_30_audio_7.wav',
#  'rec_30_audio_10.wav',
#  'rec_30_small_audio_0.wav',
#  'rec_30_audio_6.wav',
#  'rec_31_audio_4.wav',
#  'rec_31_audio_16.wav',
#  'rec_31_audio_5.wav',
#  'rec_31_audio_15.wav',
#  'rec_31_audio_12.wav',
#  'rec_31_audio_13.wav',
#  'rec_31_audio_9.wav',
#  'rec_31_audio_2.wav',
#  'rec_31_audio_14.wav',
#  'rec_31_audio_0.wav',
#  'rec_31_audio_3.wav',
#  'rec_31_audio_6.wav',
#  'rec_31_audio_10.wav',
#  'rec_31_audio_11.wav',
#  'rec_31_audio_7.wav',
#  'rec_31_audio_17.wav',
#  'rec_31_audio_8.wav',
#  'rec_31_audio_1.wav',
#  'rec_31_small_audio_0.wav',
#  'rec_31_audio_27.wav',
#  'rec_31_audio_20.wav',
#  'rec_31_audio_22.wav',
#  'rec_31_audio_24.wav',
#  'rec_31_audio_29.wav',
#  'rec_31_audio_21.wav',
#  'rec_31_audio_23.wav',
#  'rec_31_audio_18.wav',
#  'rec_31_audio_28.wav',
#  'rec_31_audio_25.wav',
#  'rec_31_audio_19.wav',
#  'rec_31_audio_26.wav',
#  'rec_32_audio_7.wav',
#  'rec_32_audio_8.wav',
#  'rec_32_audio_16.wav',
#  'rec_32_audio_6.wav',
#  'rec_32_audio_5.wav',
#  'rec_32_audio_15.wav',
#  'rec_32_audio_13.wav',
#  'rec_32_audio_4.wav',
#  'rec_32_audio_3.wav',
#  'rec_32_small_audio_0.wav',
#  'rec_32_audio_9.wav',
#  'rec_32_audio_0.wav',
#  'rec_32_audio_17.wav',
#  'rec_32_audio_1.wav',
#  'rec_32_audio_14.wav',
#  'rec_32_audio_19.wav',
#  'rec_32_audio_2.wav',
#  'rec_32_audio_11.wav',
#  'rec_32_audio_10.wav',
#  'rec_32_audio_12.wav',
#  'rec_32_audio_18.wav',
#  'rec_33_audio_2.wav',
#  'rec_33_audio_3.wav',
#  'rec_33_audio_17.wav',
#  'rec_33_audio_19.wav',
#  'rec_33_audio_15.wav',
#  'rec_33_audio_11.wav',
#  'rec_33_audio_1.wav',
#  'rec_33_audio_22.wav',
#  'rec_33_audio_10.wav',
#  'rec_33_audio_6.wav',
#  'rec_33_audio_21.wav',
#  'rec_33_audio_4.wav',
#  'rec_33_audio_20.wav',
#  'rec_33_audio_18.wav',
#  'rec_33_audio_16.wav',
#  'rec_33_audio_8.wav',
#  'rec_33_audio_0.wav',
#  'rec_33_audio_12.wav',
#  'rec_33_audio_23.wav',
#  'rec_33_audio_7.wav',
#  'rec_33_audio_14.wav',
#  'rec_33_audio_5.wav',
#  'rec_33_audio_9.wav',
#  'rec_33_audio_13.wav',
#  'rec_33_audio_27.wav',
#  'rec_33_audio_26.wav',
#  'rec_33_audio_29.wav',
#  'rec_33_audio_31.wav',
#  'rec_33_audio_24.wav',
#  'rec_33_audio_28.wav',
#  'rec_33_audio_30.wav',
#  'rec_33_audio_25.wav',
#  'rec_34_audio_16.wav',
#  'rec_34_audio_6.wav',
#  'rec_34_audio_10.wav',
#  'rec_34_audio_14.wav',
#  'rec_34_audio_3.wav',
#  'rec_34_audio_7.wav',
#  'rec_34_audio_18.wav',
#  'rec_34_audio_8.wav',
#  'rec_34_audio_11.wav',
#  'rec_34_audio_1.wav',
#  'rec_34_audio_2.wav',
#  'rec_34_audio_0.wav',
#  'rec_34_audio_9.wav',
#  'rec_34_audio_13.wav',
#  'rec_34_audio_12.wav',
#  'rec_34_audio_17.wav',
#  'rec_34_audio_4.wav',
#  'rec_34_audio_5.wav',
#  'rec_34_audio_15.wav',
#  'rec_34_small_audio_0.wav',
#  'rec_34_audio_20.wav',
#  'rec_34_audio_19.wav',
#  'rec_27_big_audio_0_chunk_1.wav',
#  'rec_26_big_audio_1_chunk_0.wav',
#  'rec_27_big_audio_0_chunk_0.wav',
#  'rec_26_big_audio_1_chunk_1.wav',
#  'rec_23_big_audio_1_chunk_0.wav',
#  'rec_27_big_audio_1_chunk_1.wav',
#  'rec_23_big_audio_1_chunk_1.wav',
#  'rec_27_big_audio_1_chunk_0.wav',
#  'rec_27_big_audio_4_chunk_0.wav',
#  'rec_27_big_audio_3_chunk_2.wav',
#  'rec_27_big_audio_3_chunk_0.wav',
#  'rec_27_big_audio_4_chunk_1.wav',
#  'rec_27_big_audio_5_chunk_0.wav',
#  'rec_27_big_audio_3_chunk_3.wav',
#  'rec_27_big_audio_3_chunk_1.wav',
#  'rec_27_big_audio_6_chunk_0.wav',
#  'rec_27_big_audio_5_chunk_1.wav',
#  'rec_27_big_audio_6_chunk_1.wav',
#  ...]

# %%
len(x)
# Out:
# 1184

# %%
aud = x.index("rec_01_audio_0.wav")
aud
# Out:
# 1005

# %%
audio_path = f"{data_dir}{x[aud]}"
audio_path
# Out:
# '/content/drive/MyDrive/Habiganj_Audio/all_audios/rec_01_audio_0.wav'

# %% [markdown]
# # Bangla Wav2Vec2-large

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/auditi41/wav2vec2-large-xlsr-53-Bengali"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

# %%
external_id = []
contents = []
errors = []
c = 0
#c&i = []

def once(output,i):

    external_id.append(i)

    if len(output['text']) == 0:
        contents.append("<>")
    else:
        contents.append(output['text'])


def again(audio,i):

    global c

    try:
        output = query(audio)

        if 'error' in output.keys():
            if c != 5:
                c += 1
                again(audio)
            else:
                c = 0
                external_id.append(i)
                contents.append("<>")
                pass
        else:
            once(output,i)


    except Exception as e:
        again(audio,i)


for i in x:

    audio = f"{data_dir}{i}"


    try:
        output = query(audio,i)
        once(output)

    except:
        again(audio,i)

# %%
print(errors)
print()
print(len(errors))
# Out:
# []
#
# 0

# %%
print(external_id)
print()
print(len(external_id))
print()
print("=======================")
print()
print(contents)
print()
print(len(contents))
# Out:
# ['rec_06_audio_8.wav', 'rec_06_audio_6.wav', 'rec_06_audio_0.wav', 'rec_06_audio_5.wav', 'rec_06_audio_3.wav', 'rec_06_audio_2.wav', 'rec_06_audio_1.wav', 'rec_06_audio_22.wav', 'rec_06_audio_14.wav', 'rec_06_audio_21.wav', 'rec_06_audio_13.wav', 'rec_06_audio_16.wav', 'rec_06_audio_10.wav', 'rec_06_audio_17.wav', 'rec_06_audio_19.wav', 'rec_06_audio_11.wav', 'rec_06_audio_23.wav', 'rec_06_audio_12.wav', 'rec_06_audio_18.wav', 'rec_06_audio_15.wav', 'rec_06_audio_20.wav', 'rec_06_audio_9.wav', 'rec_06_audio_35.wav', 'rec_06_audio_33.wav', 'rec_06_audio_30.wav', 'rec_06_audio_34.wav', 'rec_06_audio_29.wav', 'rec_06_audio_36.wav', 'rec_06_audio_25.wav', 'rec_06_audio_38.wav', 'rec_06_audio_31.wav', 'rec_06_audio_27.wav', 'rec_06_audio_28.wav', 'rec_06_audio_37.wav', 'rec_06_audio_26.wav', 'rec_06_audio_24.wav', 'rec_06_audio_32.wav', 'rec_06_audio_48.wav', 'rec_06_audio_44.wav', 'rec_06_audio_45.wav', 'rec_06_audio_46.wav', 'rec_06_audio_51.wav', 'rec_06_audio_43.wav', 'rec_06_audio_47.wav', 'rec_06_audio_40.wav', 'rec_06_audio_41.wav', 'rec_06_audio_49.wav', 'rec_06_audio_50.wav', 'rec_06_audio_42.wav', 'rec_06_audio_39.wav', 'rec_06_audio_66.wav', 'rec_06_audio_56.wav', 'rec_06_audio_60.wav', 'rec_06_audio_55.wav', 'rec_06_audio_62.wav', 'rec_06_audio_58.wav', 'rec_06_audio_65.wav', 'rec_06_audio_54.wav', 'rec_06_audio_64.wav', 'rec_06_audio_57.wav', 'rec_06_audio_63.wav', 'rec_06_audio_61.wav', 'rec_06_audio_59.wav', 'rec_06_audio_52.wav', 'rec_06_audio_53.wav', 'rec_06_audio_68.wav', 'rec_06_audio_67.wav', 'rec_06_small_audio_0.wav', 'rec_07_audio_2.wav', 'rec_07_audio_16.wav', 'rec_07_audio_0.wav', 'rec_07_audio_15.wav', 'rec_07_audio_13.wav', 'rec_07_audio_1.wav', 'rec_07_audio_14.wav', 'rec_07_audio_4.wav', 'rec_07_audio_10.wav', 'rec_07_audio_8.wav', 'rec_07_audio_7.wav', 'rec_07_audio_11.wav', 'rec_07_audio_12.wav', 'rec_07_audio_5.wav', 'rec_07_audio_9.wav', 'rec_07_audio_3.wav', 'rec_07_audio_6.wav', 'rec_07_audio_21.wav', 'rec_07_audio_25.wav', 'rec_07_audio_22.wav', 'rec_07_audio_24.wav', 'rec_07_audio_20.wav', 'rec_07_audio_19.wav', 'rec_07_audio_26.wav', 'rec_07_audio_18.wav', 'rec_07_audio_17.wav', 'rec_07_audio_23.wav', 'rec_07_small_audio_0.wav', 'rec_08_audio_1.wav', 'rec_08_audio_0.wav', 'rec_08_audio_4.wav', 'rec_08_audio_5.wav', 'rec_08_audio_11.wav', 'rec_08_audio_14.wav', 'rec_08_audio_9.wav', 'rec_08_audio_2.wav', 'rec_08_audio_17.wav', 'rec_08_audio_10.wav', 'rec_08_audio_15.wav', 'rec_08_audio_12.wav', 'rec_08_audio_6.wav', 'rec_08_audio_3.wav', 'rec_08_audio_16.wav', 'rec_08_audio_13.wav', 'rec_08_audio_7.wav', 'rec_08_audio_8.wav', 'rec_08_audio_24.wav', 'rec_08_audio_18.wav', 'rec_08_audio_26.wav', 'rec_08_audio_25.wav', 'rec_08_audio_19.wav', 'rec_08_audio_21.wav', 'rec_08_audio_28.wav', 'rec_08_audio_23.wav', 'rec_08_audio_27.wav', 'rec_08_audio_22.wav', 'rec_08_audio_20.wav', 'rec_08_small_audio_0.wav', 'rec_09_audio_3.wav', 'rec_09_audio_2.wav', 'rec_09_audio_10.wav', 'rec_09_audio_9.wav', 'rec_09_audio_0.wav', 'rec_09_audio_4.wav', 'rec_09_audio_1.wav', 'rec_09_audio_8.wav', 'rec_09_audio_5.wav', 'rec_09_audio_7.wav', 'rec_09_audio_6.wav', 'rec_09_audio_14.wav', 'rec_09_audio_26.wav', 'rec_09_audio_25.wav', 'rec_09_audio_11.wav', 'rec_09_audio_23.wav', 'rec_09_audio_20.wav', 'rec_09_audio_29.wav', 'rec_09_audio_16.wav', 'rec_09_audio_13.wav', 'rec_09_audio_17.wav', 'rec_09_audio_28.wav', 'rec_09_audio_12.wav', 'rec_09_audio_24.wav', 'rec_09_audio_15.wav', 'rec_09_audio_27.wav', 'rec_09_audio_21.wav', 'rec_09_audio_18.wav', 'rec_09_audio_19.wav', 'rec_09_audio_22.wav', 'rec_09_audio_42.wav', 'rec_09_audio_37.wav', 'rec_09_audio_33.wav', 'rec_09_audio_46.wav', 'rec_09_audio_47.wav', 'rec_09_audio_35.wav', 'rec_09_audio_44.wav', 'rec_09_audio_36.wav', 'rec_09_audio_32.wav', 'rec_09_audio_40.wav', 'rec_09_audio_41.wav', 'rec_09_audio_39.wav', 'rec_09_audio_31.wav', 'rec_09_audio_34.wav', 'rec_09_audio_43.wav', 'rec_09_audio_38.wav', 'rec_09_audio_30.wav', 'rec_09_audio_45.wav', 'rec_09_audio_48.wav ...
#
# 1184
#
# =======================
#
# ['<>', '<>', 'ড়॥়‚দ‚ড় ৰউড়lড়য়নফ়‚aড়য়পড়াটয়ঁদ‚অগয়নঙlআয়জঝরৎফড়ঊঅড়ঊনগফlড়স জউফড় অঁগঊঅঘফড়॥ছঅlড়াড়ুঅৈআউড়॥পইaায়নউড়পইইঅগপঅ‚ড়ঙঅইঙঁধlaড়থজউজগঁঅড়হaগড়ৈধঁঁড় উঊইড়া উফউড়lৈঅlড় দউ‚অগফড়ঊaaড়ইঙllড়ঙঊউঅঃদ‚ঃঁদ‚aড়ঙlনগঅড়ঙঝঅগঅনড়pউড়ইঅঝদয়গlঅড়ইঃয়অঃফউড়উঙঅইঁদ‚অই অউ‚অ।ড়', 'ঊঅড় অফউড় ঝফড়ই অয়নফড় উঝঅlড়lইঅড়ঃফ‚ফড়—‚টaৎঊআঁ‚ড়lঅআঊজগ‚ড়দয়উ‚দঊড়lঅঘঅআড় ঊঅড়সহগঅআউউড়ঃউইযড়‚উaঁফড়ঙঝফঙজগঘফউড়ায়নউড় উ‚ইঅড়টগড়শয়অlদ‚ড়ইঅlঙগফউড়ঁউবঁঅউগ।ড়', 'lঊaঊয়নফংফউড়টঅঊগয়নড়পজউধজড়ঊa‚ গইৰঁঊফঊড়ঘজইaগঁ‚ঙনফড়হaগঊঃদ‚ঘউঘl‚ফউড় দউ‚দয়ড়ঙ‚ঊ়গফহaড়lফড়য়ঝফফড়ঁঁদ‚অসউঅড়poঢঙঁইঅউড়ঁউঊঅয়নড়সুঅড়ঙফঃফড়pঅড়lঅপউড়—ুঅগঅঁফগফউড়ঃজঊaকড়সউঅড়য়উঝlফড়আধব‚ঙউড় উঊঅয়ন।ড়', 'ঃঅনড়ঘaউদইঙয়‚অআয়নঅউড়ঙহফফড়্ড়y়llঘদ‚ইড় অড়lইফড়‚ ৈফড়গফপগফাড়টaহফাঅড়॥উঙঅঘঅঁয়ফড়॥ঁlড়ইঙঅpউঊঅlঘa‚ফড়ঁউফড়সঙalllঅসৈঅlবড়lপউঙড়ঃকঊঅঊঃঅউ‚ড়ঙlফড় ঙফআড়lদয়‚অড় য়নবদ‚‚সুঅড়‚দউজুa‚ড়উঅৈঅউফড়ঃউছঅ ফয়নফড়yগফগউঅ।ড়', 'নগঅয়নঝইজঁউঅইদঊউউড়য়অগঅylদয়ড়ছফগফউগঅ উয়জঁদ‚aড়ৈঅঁইঅড়ঝlঙ‚দয়ড়ই‚অড়ঁগঁড়laঊঅ‚দউlঅড়য়‚অগফয়নঅআয়নড়উজইlঅয়অড়ঁpllফহঅনড়‚অউঅড়ylয়ঙড়ইড়্গদয়ফড়উবঁড় দউইইঙয়ফউড়ঁ ড়গয়নlঅগযড়থজউদ‚aফড়yথঅড়থজউউড়ঁউফ।ড়', '—lদয়অড়ঙলফylজঊঅউঅড়lফ‚দউlফউড় ফঃদ‚aুaড়॥পউদ‚গযড়়অ aঘড়্অয়নফড়ঃদছa‚ঁ ঊফ‚aড়ঃগঊধদ‚aসআড়ঁখঝজউaধদুফড়সঁুaঝফড়ৈইগঅড়॥ঙlদ়গ‚ড়ঙঅঁউফ।ড়', 'অড়ঁুদ‚অড়ঙউ‚সনঅউ উফড়সউঅড়সসঁঝlড়ইউউaড়উফড়ঁদগঅড় দউ‚aথঅড়‚উুফড়ঙায়নঅউড়ঙaঃফঊঅউঅড়ঙয়নফহফড়॥ুড়ঊঅ—lগঅট‚ড়ইaড়সঊউফগঅঘঅংaড়উউঘঅড়pগফড়ইaঙ দউঊঅুঅড় অঃ অঁa‚ফlড়ঙয়নঁগঅপড়ঁlজঊঅঝঅড়হaগড়ঘইঅড়ঊaয়নঅগড়ঁউফাঃঁফড়yই অআঃaগ।ড়', 'অড়ঊঙlড়ঙয়নঃদ‚অড়টৈঅগদয়য়নঅৈঁঅগফড়॥আঃছফ‚গঅ জ‚ঊ‚ড়ঊহউঅউড়ঁlড়ড়ঁউফড়ঘজঊগফড়ঝইইlঅঢফ‚উইফঃ‚ড়ঘযঊlড়ঊঙঘযগড়l‚ঁয়গঅpঅউঘফঙউড়‚অঝফপউড় অ‚ফউয়ফঝঅlaড় অনউড়টঅ দউঁহফঘফফড়yঃইজঃফুআঊয়নড়াঝlঊঙaধয়নফটa‚ফয়নঅড়lঅড়ঙউফড়aঃজড়oউaৈঅউড়ঊঅড়॥ঊaঃগঅ‚ড়ঙঅঊফউড়॥ইড়ঁঅউফড়', 'ঁoথফড়ঁুaড়উ্aড়াড়ঝফাঊউড়ুউফঁঅঊঅlফঃফ অঁফড়yঊaঃদখ‚aড়ঃঊউঅউড়ঊ‚ঁঅুaড়ঃইদয়ন‚ইঙড়াড়সগঘঅড়ইaগo‚অঃড়গড়ঙইফুড়ঘফথঃদুজুজড়ঘaয়নফড়ylaয়ফpঅড়‚বlগঅঘঅড়ইaগফ‚দয়অগয়ন‚অড়বlদুড়‚গঃড় অঙড়aaঃইঘদয়অগঅয়নa ড় ঃগঅlড়ঊনঝফঊঝa‚কগঅপফড়টফগদগফড়ঙকগঅউফ।ড়', 'ঘalড়ঙঅগদয়॥ইaড়ইঅঁঙঝড়য়ফড়ঃঅঙal অঊঃদ‚ড়্a‚‚অঁড়ই‚অll‚অড়ঝpaউড়॥ইঅুalদঝalড়ঘঅউড়ঃঊড়lঅইlঅটঙইlটঅঙফড়ঊlদaউদঊঅঘড়ঁ॥ঙlঃঅঙফউড়য়ফ‚অড়ইlঁউফড়ঁগদয়অড়পউজ ঘউ‚ড়ঙউঙউ।ড়', 'ঊদয়অlঅইংঅড়উড়॥ইফাবয়নঅউড়সংবঝগঊঅঊaড়ঙউঅয়নইঅউড়হফlুটঅঊaড়yুইঁoগযlঝযlllঅইফ বুইড়ঊআগalড়ঝফইalঅঅউা‚ড়ইবঊঅগaঁড়ঝalফয়নঅড়উআনগফাড়ুদউঅয়নঊদয়অঝদ়অউঁযড় বlউয়উঅঝঅউঅড়॥ঝঘড়ঘদঊযঊফড়আঊঅlড়সইউঅlড়ঙয়নফড়‚ala।ড়', 'নগফসফঘফউঅ‚অ‚অড়ঊaঘঅla‚a॥ অ‚অড়ঁগlড়ঁথ‚ফ‚ফউড়‚ফউৈফগফগআ‚aড়ঁঅঊজউজড়ইaুফুঅউড়পদউঅ‚অড়ঝlঅইয়নউঙড়হaফড়বঘpয়অড়ইঅঁঊঅউফড়ঝঅঊঅৈঅlড়lঅড়ঘঙগlঅড়পaয়নফ।ড়', 'উঙঅঝড়lঅৈঅয়ন দউ উঊউড়lঅঙঅ‚ফড়ঝফগঅড়ঘৰউইনফl অগ‚ ‚ঙউড়ড় দউ‚aড়lনঊফড়ঘজ‚জইঃঅঘaড়পফগ ফড়গ‚ড়ylঅlফগফনড়ঙবঃঙউঃফড়ঙঅয়নঅঃফড়ঙ‚‚ঙঃ‚ফড়ইড়ঙ্উড়সঃইদয়অlফ।ড়', 'টঅঊaড়স্‚ড়সপaড় ঙইaইউঅঃইঅঃদুঅড়াড়ইঅlফউঃঅঊফয়ফঁদুফাড়্উহফসl‚আরদঝফlaয়নঅউড়হঅঁউফটঅঙনযহঅগঅড়রদ়alফড়উaইফউ ফ‚lংফৈoফ‚alদপalaপগগফ‚ঝড়ইফনড়পউlড়ঃঅৈফড়হঅঁউaড়lঅঙয়নড়ঊদগফা‚অগফ।ড়', 'হ‚ঃঃঘথড় দয়অড়ঙউৎঅউটউুlaনঅড়্ফগফঊফফlড়াঢalড়ৈজইঊঅড়ঙaঃফঘজাড়ঙঅউড়ঊঅআঝফউড়গঅৈঃঅউড়—উঘঅ উফড়য়‚অঊঅড়ঁজইউফআড়lঅঃড়সগ ড় অঁইঅlয়য়নঘদ‚lঅড়yঘযlঅড়‚অঘফউড়y‚উদৎড়ঃউদয়অঃ‚ঁদঝঅয়নগঅড়্অঃ‚গঅটড়ঁউফl।ড়', '‚ফড় উঃদ‚জ অউaড়ইঙফউa‚ফড়ঙফঃaড়ঘফগঊফড় ঝlড়॥ঊগaঁড়ঊঙজগবড়গaঊৎফড়সঁড়ঊউইlফড়আড় উজ উড়॥ অউঅইঅঅড়উাড়নসঁফড় দউ়অঃফড়—ঘ য়ফড়ঁউফড়ঁlড়গঅ ‚ড়ঙয়নফড়ঘফৈফহঅউঁফড়হঅপফাড়‚alaড়য়অঊউঅুড়ৈবlদুগঅৈুফড়ঙায়নাড়yঊlড়ঃঅআঁঅউফউড়ঘঅ।ড়', 'ইllঘউড়টউঊঝ‚aঁড় সফ‚অঙঁঊঅড়ঃফয়নঅগড়গদয়অটড়ঊঙaউঅড় পঅউড়‚ড়ৈয়অlফউফড়সউ ড়॥‚উপছaড়ৈঅইঅগফঘঅনড়পlয়জপদঘঅঘফউ‚য়নফহফlড়গঊ॥ঘঝঅইঅড়হবুড়সঃফlঅড়য়নড়পউঊ‚যlঅড়ঁুঅড়ঁুঅড়ঁউফ।ড়', 'গয়য়ই‚অঁফড় দউ‚অথ অlঅড়ঁগগঅইড়lফড়ঙইঁয়নউঃঅড়ঊঁড়‚ঊড়‚অঊঅউড় উ উইlঅ‚উঅড়ৈ‚l—ু‚ফড়॥ উঊlদlঁউদয়ফয়নফড়—ও জউ।ড়', 'সয়‚ফড়ঁগদ ড়ঁুদুঅহফউঅঝaউ জইদড়ঙঃ‚ই জউড় apঊফফগড়ঁজজ জউৎড়উ‚ঁদ‚গজ ়ঘউড় উa়ফ ড়ইঅগফড়lঅঘফড়lঘগফড়়ফlদংড়lফউঅড়সঁটঅ‚ফইফয়নফড়॥ঃফড়থaঁদগড়সটঅড়়aঁফুড় য়নউঅড়সউনফহফড়ঁঙlফড়সঊঅআড়ঝফঁফড়ঁউফফড়ইয়নফগঅপaড়ছফঁফড়হoঘaঁফ।ড়', 'সঁগঅঊঙa‚ঁহউশয়অফসআড়ঊউঊঅআঊদয়অকঁড়ঁ aহঅঁবlড়ঊদয়অগইঁঅউড়ylদয়‚ oঝফড়ঊঅঊaড়ঘঅঙঅড়আঃগঅইযড়ঊঅংনaড়ঝই।ড়', 'গঅপফঊফla‚অইlঊaঃঃফইউড়ঊয়‚ইঅড়॥ঝফড়ঙঅঝঅগড়ঁড়ঘaগদয়ফড়ৈউঅড়টউঊফউসঁগঅড়ঙ‚ফথঅঁধঅড়—ঃইড়ঙয়নফহফঁআঃlঅইড়ঊরদ়অ‚অঘফআড়lঅই‚ই়অয়নঊড়ঁদয়নঅ ড়ায়নফ ৰউদঊগঅড়ইlপয়অদঅড়ঙlউফৈফড়ঙঅগঁফড়া‚জউড়ঊদয়‚lড়ঘঅড়ঁl।ড়', '— lগফড়ঘজআড়‚aপঅড়ঙaঃফডউlঅড়‚ঊaহaগlায়নঅইঅড়॥ইalঅইaুaড়ঘজআড়ঘঅ দ উaহঅড়laগয়নড়হঊঅয়অয়ফড়llদফউড়া্অlড়্অউঘফড়ঝঅঙইঅlফংঅঁঅড় ায়নঅ্অউড়ঘফউ‚দ‚ন‚ড়yঊঅড়উঙlয়নৎফউড়lড়ঃaগaয়নড়ঝlদয়ঁড়ঝoগঅউড়ঃদঁজগড়ঙ।ড়', 'ঘৰউউঅঊফউজড়ইবয়নঅড়উঊaঃদ‚অইবইঅউফফ‚ইদ অlaড়য়অঃড়laইlফড় উ‚অঘফগবয়নঅঘফউড়ড়yড়ঙঅহঅউফড়ঁঙইড় ফ‚অড় বllঅলদপaঅউড়ঊদয়পlঅপড়ঘউইফউড়উড়ঙঊফlজঁৈlড়ঁয়নফড়ঃড়ই‚ঘঅড়ইঅlজধঅউড়সঁুঅড়উlড়ঃজ অউড় অউa়অগঅঃড়ৈউ।ড়', 'ই অlগফড়॥ইঅইaঘযউ‚গঅঘইঅআড়—llদঘড়ঁঅগফড়য়ফঙগফআ॥ঙঅগড়ঊঅঊঅড়অড়pফউগফহফ।ইঙlড়ঙয়নফঃ‚alaড়সআড়ঊঃড়॥pঙঘঃঅড়ঝlঅড়‚অpঊগড়lফউড়ঃফঊফকড়ডুঅড়ঙগ‚ডউঅড়ঊaজ‚ড়ঘফথঅগaড়ঘঊঅউঅড়—ঘঅঊঅড়ঙঅপজড়॥পlঅড়॥থaয়নঅড়য়অউঅড়ইlঅ‚ উগঅঊউগউঊড়', '‚অউড় খpআগঅড়‚alদগঅlড়॥উ‚অlঃ॥lদlঙঅড়pউফড়পণউঅড়ঁফড়yড়ঊগগঙফড়়অ‚অড়পৎঅঁউ উঅড়‚‚ড়ইঙ ...
#
# 1184

# %%
num = x.index("rec_19_audio_12.wav")
num
# Out:
# 474

# %%
audio_path = f"{data_dir}{x[num]}"
audio_path
# Out:
# '/content/drive/MyDrive/Habiganj_Audio/all_audios/rec_19_audio_12.wav'

# %%
import audiosegment

print(f"File name :",audio_path)
audiosegment.from_file(audio_path)
# Out:
# File name : /content/drive/MyDrive/Habiganj_Audio/all_audios/rec_19_audio_12.wav
# /content/drive/MyDrive/Habiganj_Audio/all_audios/rec_19_audio_12.wav: 1 channels, 16 bit, sampled @ 16.0 kHz, 15.392s long

# %%
quick_transcription = query(audio_path)
quick_transcription
# Out:
# {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}

# %%
num = x.index("rec_19_audio_31.wav")
num
# Out:
# 473

# %%
audio_path = f"{data_dir}{x[num]}"
audio_path
# Out:
# '/content/drive/MyDrive/Habiganj_Audio/all_audios/rec_19_audio_31.wav'

# %%
import audiosegment

print(f"File name :",audio_path)
audiosegment.from_file(audio_path)
# Out:
# File name : /content/drive/MyDrive/local_speech/Rangpur/chunks/rangpur_all/rec_19_audio_31.wav
# /content/drive/MyDrive/local_speech/Rangpur/chunks/rangpur_all/rec_19_audio_31.wav: 1 channels, 16 bit, sampled @ 16.0 kHz, 15.264s long

# %%
quick_transcription = query(audio_path)
quick_transcription
# Out:
# {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}

# %% [markdown]
# # Making Dataframes

# %%
import pandas as pd

df = pd.DataFrame(list(zip(external_id, contents)), columns =['External_ID', 'Contents'])
df.head()
# Out:
#           External_ID                                           Contents
# 0  rec_06_audio_8.wav                                                 <>
# 1  rec_06_audio_6.wav                                                 <>
# 2  rec_06_audio_0.wav  ড়॥়‚দ‚ড় ৰউড়lড়য়নফ়‚aড়য়পড়াটয়ঁদ‚অগয়নঙlআয়জঝরৎফড়ঊঅড়...
# 3  rec_06_audio_5.wav  ঊঅড় অফউড় ঝফড়ই অয়নফড় উঝঅlড়lইঅড়ঃফ‚ফড়—‚টaৎঊআঁ‚ড়lঅ...
# 4  rec_06_audio_3.wav  lঊaঊয়নফংফউড়টঅঊগয়নড়পজউধজড়ঊa‚ গইৰঁঊফঊড়ঘজইaগঁ‚ঙনফ...

# %%
df
# Out:
#               External_ID                                           Contents
# 0      rec_06_audio_8.wav                                                 <>
# 1      rec_06_audio_6.wav                                                 <>
# 2      rec_06_audio_0.wav  ড়॥়‚দ‚ড় ৰউড়lড়য়নফ়‚aড়য়পড়াটয়ঁদ‚অগয়নঙlআয়জঝরৎফড়ঊঅড়...
# 3      rec_06_audio_5.wav  ঊঅড় অফউড় ঝফড়ই অয়নফড় উঝঅlড়lইঅড়ঃফ‚ফড়—‚টaৎঊআঁ‚ড়lঅ...
# 4      rec_06_audio_3.wav  lঊaঊয়নফংফউড়টঅঊগয়নড়পজউধজড়ঊa‚ গইৰঁঊফঊড়ঘজইaগঁ‚ঙনফ...
# ...                   ...                                                ...
# 1179  rec_05_audio_39.wav                                                 <>
# 1180  rec_05_audio_38.wav                                                 <>
# 1181  rec_05_audio_40.wav                                                 <>
# 1182   rec_06_audio_7.wav                                                 <>
# 1183   rec_06_audio_4.wav                                                 <>
#
# [1184 rows x 2 columns]

# %%
df.to_csv("Bangla-wav2vec2-habiganj-inference.csv")

# %%
df.to_excel("Bangla-wav2vec2-habiganj-inference.xlsx")
